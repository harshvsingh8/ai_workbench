# %% [markdown]
# # Coding Attention Mechanism
#
# ![image.png](attachment:image.png)
#
# The development of the attention module which would later be integrated in the LLM
# architecture would happen in *four* stages.
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy
import torch
import re
